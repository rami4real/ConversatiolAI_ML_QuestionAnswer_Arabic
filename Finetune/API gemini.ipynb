# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyBpaiWD88OMb1ZVtxHWFK8pyyLGR2czjbY")

# Make sure the model name is correct and accessible
model_name = "tunedModels/finalcopyof-arabicmlnocsv-msft87lmtszj"
model = genai.GenerativeModel(model_name=model_name)

# The prompt might need adjustment or rephrasing
prompt =  "اشرح البيانات المفقودة بشكل مبسط. قدم أمثلة واقتراحات للتعامل معها"
result = model.generate_content(prompt)

# Check if the result contains any candidates before accessing 'text'
if result.candidates:
    print(result.text)
else:
    print(f"Model did not generate any content for the prompt: {prompt}")
    print(f"Response details: {result}") # Print the response for debugging
# Out:
# ##  البيانات المفقودة:
#
# **البيانات المفقودة** هي قيم غائبة في مجموعة بيانات. يمكن أن تنتج من أخطاء إدخال، تالفة، غياب معلومات، أو حتى اختيارات متعمدة.
#
#
# **مثلاً:**
#
# * قوائم تسوق بدون أسعار بعض المواد
# * استبيان مع أسئلة مُجهولة الإجابة
# * ملفات تعريفية على شبكات التواصل الاجتماعي بدون تاريخ ميلاد
#
# **الآثار:**
#
# البيانات المفقودة يمكن أن تؤثر على دقة تحليلاتك و تنبؤاتك، وإعطائك رؤى خاطئة.
#
# **إليك بعض الطرق لمعالجة البيانات المفقودة:**
#
# 1. **الحذف**:
#
#    * **الحذف الكامل**: إزالة كامل القيم المفقودة من مجموعة البيانات. لكنّ ذلك قد يؤدي إلى فقد معلومات قيمة.
#    * **الحذف جزئي**: حذف فقط القيم المفقودة في السجلات.
#
# 2. **الاستبدال**:
#
#    * **الاستبدال بالمتوسط**: استبدال القيم المفقودة بالمتوسط أو الوسيط.
#    * **الاستبدال بعلاقات بين القيم**: استخدام علاقات بين متغيرات أخرى في مجموعة البيانات.
#    * **الاستبدال بملء القيم**: التوقع باستخدام البيانات المتاحة في القيم المفقودة، ويساعد في المحافظة على القيم المتواجدة.
#
# 3. **الاستخدام**:
#
# ...

# %%
print(result,"'meteor metric","trl")
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...
